# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import japanize_matplotlib

# %%
# データ生成
np.random.seed(42)  # 再現性のための乱数シード

# 生理周期の分布
cycle_mean = 20.73
cycle_std = 8.35

# 生理期間の分布
organ_mean = 4.07
organ_std = 1.76

# サンプル数と周期数
num_samples = 100
num_cycles = 4

# 各IDごとにデータ生成
data = []
for id in range(num_samples):
    # IDごとの生理周期の基準値を設定
    base_cycle = np.random.normal(cycle_mean, cycle_std) # 基準値を生成
    
    while True:
        # 生理周期のサンプリング (基準値を中心に標準偏差8.35で生成)
        cycles = np.random.normal(base_cycle, 8.35, num_cycles)
        cycles = np.clip(cycles, 7, 90)  # 生理周期は7以上90以下に制約
        
        # 生理期間のサンプリング
        organs = np.random.normal(organ_mean, organ_std, num_cycles)
        organs = np.clip(organs, 2, np.inf)  # 生理期間は1以上に制約
        
        # 生理周期が生理期間より必ず長いか確認
        if np.all(cycles > organs):
            break  # 条件を満たした場合、ループを抜ける
    
    data.append({
        "ID": id,
        "Base_Cycle": base_cycle,  # 基準値を保存
        "Cycles": cycles,
        "Organs": organs
    })

# データフレーム化
df = pd.DataFrame(data)
df = df.explode(["Cycles", "Organs"]).reset_index(drop=True)
df["Cycle_Index"] = df.groupby("ID").cumcount() + 1
print(df)
# Out:
#      ID  Base_Cycle     Cycles    Organs  Cycle_Index
# 0     0   24.877563  23.723056  3.657919            1
# 1     0   24.877563  30.285762  6.849415            2
# 2     0   24.877563  37.594862  5.420685            3
# 3     0   24.877563  22.922382  3.243725            4
# 4     1   25.260376  21.390839       2.0            1
# ..   ..         ...        ...       ...          ...
# 395  98   16.094084  19.768205  4.499089            4
# 396  99   16.019943    15.6393       2.0            1
# 397  99   16.019943  18.051828  6.611026            2
# 398  99   16.019943  14.005622  3.925414            3
# 399  99   16.019943  18.959606  6.036441            4
#
# [400 rows x 5 columns]

# %%
from scipy.stats import norm

# 各IDごとにモデルを作成
results = []
for id, group in df.groupby("ID"):
    # 10サイクル目までのデータを使用
    train_data = group[group["Cycle_Index"] < num_cycles]
    
    # 11サイクル目のデータを予測対象
    test_data = group[group["Cycle_Index"] == num_cycles]
    
    
    # 平均値と分散を計算
    cycle_mean = train_data["Cycles"].mean()
    cycle_std = train_data["Cycles"].std()
    
    # 次の生理周期の予測
    predicted_cycle = cycle_mean
    
    # 信頼区間の計算 (95%信頼区間)
    lower_bound = norm.ppf(0.1, loc=cycle_mean, scale=cycle_std)
    upper_bound = norm.ppf(0.9, loc=cycle_mean, scale=cycle_std)
    
    # 実測値
    actual_cycle = test_data["Cycles"].values[0]
    
    results.append({
        "ID": id,
        "Predicted_Cycle": predicted_cycle,
        "Actual_Cycle": actual_cycle,
        "Lower_Bound": lower_bound,
        "Upper_Bound": upper_bound
    })

# 結果の表示
for result in results:
    print(f"ID: {result['ID']}, Predicted: {result['Predicted_Cycle']:.2f}, "
          f"Actual: {result['Actual_Cycle']:.2f}, "
          f"90% CI: [{result['Lower_Bound']:.2f}, {result['Upper_Bound']:.2f}]")
# Out:
# ID: 0, Predicted: 30.53, Actual: 22.92, 90% CI: [21.64, 39.43]
# ID: 1, Predicted: 23.35, Actual: 9.28, 90% CI: [18.98, 27.71]
# ID: 2, Predicted: 14.55, Actual: 13.71, 90% CI: [2.22, 26.88]
# ID: 3, Predicted: 19.71, Actual: 39.33, 90% CI: [17.80, 21.62]
# ID: 4, Predicted: 14.17, Actual: 28.64, 90% CI: [2.77, 25.56]
# ID: 5, Predicted: 17.34, Actual: 7.00, 90% CI: [9.21, 25.46]
# ID: 6, Predicted: 28.73, Actual: 32.10, 90% CI: [19.01, 38.46]
# ID: 7, Predicted: 16.58, Actual: 19.12, 90% CI: [8.86, 24.29]
# ID: 8, Predicted: 22.60, Actual: 21.16, 90% CI: [4.84, 40.36]
# ID: 9, Predicted: 24.13, Actual: 19.52, 90% CI: [10.81, 37.45]
# ID: 10, Predicted: 21.37, Actual: 18.27, 90% CI: [11.99, 30.75]
# ID: 11, Predicted: 12.72, Actual: 12.07, 90% CI: [6.36, 19.09]
# ID: 12, Predicted: 17.31, Actual: 23.38, 90% CI: [5.86, 28.75]
# ID: 13, Predicted: 8.60, Actual: 7.00, 90% CI: [5.05, 12.16]
# ID: 14, Predicted: 14.45, Actual: 19.85, 90% CI: [1.46, 27.44]
# ID: 15, Predicted: 21.73, Actual: 11.25, 90% CI: [10.51, 32.94]
# ID: 16, Predicted: 14.53, Actual: 30.63, 90% CI: [8.48, 20.57]
# ID: 17, Predicted: 30.92, Actual: 30.75, 90% CI: [19.25, 42.60]
# ID: 18, Predicted: 11.94, Actual: 15.61, 90% CI: [6.02, 17.86]
# ID: 19, Predicted: 39.82, Actual: 47.47, 90% CI: [29.93, 49.71]
# ID: 20, Predicted: 12.58, Actual: 15.45, 90% CI: [3.26, 21.91]
# ID: 21, Predicted: 19.99, Actual: 26.70, 90% CI: [11.49, 28.49]
# ID: 22, Predicted: 38.62, Actual: 29.80, 90% CI: [17.99, 59.24]
# ID: 23, Predicted: 22.91, Actual: 27.75, 90% CI: [20.04, 25.78]
# ID: 24, Predicted: 17.00, Actual: 10.82, 90% CI: [5.40, 28.60]
# ID: 25, Predicted: 20.26, Actual: 16.85, 90% CI: [3.47, 37.04]
# ID: 26, Predicted: 23.08, Actual: 20.98, 90% CI: [11.98, 34.19]
# ID: 27, Predicted: 32.95, Actual: 24.35, 90% CI: [12.95, 52.95]
# ID: 28, Predicted: 8.83, Actual: 10.88, 90% CI: [4.77, 12.90]
# ID: 29, Predicted: 25.07, Actual: 21.91, 90% CI: [8.09, 42.06]
# ID: 30, Predicted: 22.40, Actual: 34.56, 90% CI: [16.79, 28.01]
# ID: 31, Predicted: 24.11, Actual: 21.53, 90% CI: [19.27, 28.95]
# ID: 32, Predicted: 33.11, Actual: 21.32, 90% CI: [30.37, 35.85]
# ID: 33, Predicted: 25.14, Actual: 20.02, 90% CI: [15.06, 35.22]
# ID: 34, Predicted: 32.72, Actual: 34.34, 90% CI: [27.32, 38.13]
# ID: 35, Predicted: 35.25, Actual: 44.81, 90% CI: [21.19, 49.30]
# ID: 36, Predicted: 21.78, Actual: 14.47, 90% CI: [12.76, 30.81]
# ID: 37, Predicted: 20.72, Actual: 24.70, 90% CI: [16.19, 25.26]
# ID: 38, Predicted: 29.37, Actual: 23.17, 90% CI: [20.54, 38.21]
# ID: 39, Predicted: 19.23, Actual: 17.18, 90% CI: [10.37, 28.09]
# ID: 40, Predicted: 20.85, Actual: 33.66, 90% CI: [13.97, 27.72]
# ID: 41, Predicted: 23.77, Actual: 17.26, 90% CI: [5.15, 42.39]
# ID: 42, Predicted: 29.85, Actual: 16.08, 90% CI: [16.59, 43.10]
# ID: 43, Predicted: 16.99, Actual: 27.15, 90% CI: [3.40, 30.58]
# ID: 44, Predicted: 15.34, Actual: 17.98, 90% CI: [6.28, 24.40]
# ID: 45, Predicted: 34.56, Actual: 32.36, 90% CI: [22.25, 46.87]
# ID: 46, Predicted: 26.96, Actual: 10.59, 90% CI: [23.09, 30.84]
# ID: 47, Predicted: 10.98, Actual: 7.00, 90% CI: [4.89, 17.08]
# ID: 48, Predicted: 17.95, Actual: 13.04, 90% CI: [5.79, 30.11]
# ID: 49, Predicted: 12.74, Actual: 16.09, 90% CI: [4.36, 21.12]
# ID: 50, Predicted: 18.64, Actual: 10.26, 90% CI: [2.10, 35.17]
# ID: 51, Predicted: 23.21, Actual: 7.83, 90% CI: [21.48, 24.95]
# ID: 52, Predicted: 38.10, Actual: 24.48, 90% CI: [22.87, 53.33]
# ID: 53, Predicted: 12.31, Actual: 16.22, 90% CI: [0.52, 24.11]
# ID: 54, Predicted: 31.53, Actual: 26.14, 90% CI: [23.09, 39.97]
# ID: 55, Predicted: 20.62, Actual: 18.22, 90% CI: [19.73, 21.50]
# ID: 56, Predicted: 16.71, Actual: 22.92, 90% CI: [7.29, 26.13]
# ID: 57, Predicted: 22.89, Actual: 10.20, 90% CI: [14.94, 30.83]
# ID: 58, Predicted: 17.88, Actual: 20.62, 90% CI: [9.08, 26.68]
# ID: 59, Predicted: 16.74, Actual: 27.95, 90% CI: [5.81, 27.68]
# ID: 60, Predicted: 21.96, Actual: 33.58, 90% CI: [18.21, 25.71]
# ID: 61, Predicted: 17.85, Actual: 34.45, 90% CI: [13.10, 22.60]
# ID: 62, Predicted: 8.05, Actual: 7.00, 90% CI: [5.72, 10.38]
# ID: 63, Predicted: 39.61, Actual: 32.59, 90% CI: [35.43, 43.79]
# ID: 64, Predicted: 27.13, Actual: 22.48, 90% CI: [18.84, 35.42]
# ID: 65, Predicted: 20.37, Actual: 28.70, 90% CI: [15.33, 25.42]
# ID: 66, Predicted: 23.69, Actual: 46.62, 90% CI: [15.83, 31.54]
# ID: 67, Predicted: 26.95, Actual: 33.83, 90% CI: [12.64, 41.26]
# ID: 68, Predicted: 23.79, Actual: 19.88, 90% CI: [5.08, 42.49]
# ID: 69, Predicted: 13.21, Actual: 35.28, 90% CI: [7.30, 19.12]
# ID: 70, Predicted: 7.00, Actual: 13.65, 90% CI: [nan, nan]
# ID: 71, Predicted: 21.75, Actual: 20.02, 90% CI: [20.48, 23.02]
# ID: 72, Predicted: 18.55, Actual: 7.00, 90% CI: [8.61, 28.49]
# ID: 73, Predicted: 8.83, Actual: 32.26, 90% CI: [6.13, 11.53]
# ID: 74, Predicted: 16.58, Actual: 14.34, 90% CI: [5.88, 27.28]
# ID: 75, Predicted: 30.77, Actual: 27.83, 90% CI: [20.35, 41.18]
# ID: 76, Predicted: 21.41, Actual: 11.82, 90% CI: [11.14, 31.67]
# ID: 77, Predicted: 21.67, Actual: 7.71, 90% CI: [18.07, 25.27]
# ID: 78, Predicted: 18.18, Actual: 22.52, 90% CI: [11.83, 24.53]
# ID: 79, Predicted: 32.76, Actual: 33.15, 90% CI: [25.22, 40.30]
# ID: 80, Predicted: 21.45, Actual: 19.95, 90% CI: [15.72, 27.18]
# ID: 81, Predicted: 35.59, Actual: 31.07, 90% CI: [16.30, 54.87]
# ID: 82, Predicted: 43.08, Actual: 41.81, 90% CI: [32.98, 53.19]
# ID: 83, Predicted: 22.23, Actual: 7.00, 90% CI: [20.10, 24.37]
# ID: 84, Predicted: 21.25, Actual: 26.89, 90% CI: [9.88, 32.63]
# ID: 85, Predicted: 9.39, Actual: 7.00, 90% CI: [8.17, 10.61]
# ID: 86, Predicted: 22.22, Actual: 21.77, 90% CI: [14.36, 30.09]
# ID: 87, Predicted: 17.22, Actual: 13.06, 90% CI: [5.49, 28.94]
# ID: 88, Predicted: 28.63, Actual: 18.64, 90% CI: [23.02, 34.24]
# ID: 89, Predicted: 34.64, Actual: 30.51, 90% CI: [21.95, 47.32]
# ID: 90, Predicted: 22.63, Actual: 28.66, 90% CI: [8.99, 36.27]
# ID: 91, Predicted: 26.56, Actual: 44.42, 90% CI: [24.80, 28.32]
# ID: 92, Predicted: 21.08, Actual: 8.46, 90% CI: [9.43, 32.74]
# ID: 93, Predicted: 10.98, Actual: 17.33, 90% CI: [6.56, 15.41]
# ID: 94, Predicted: 34.02, Actual: 42.35, 90% CI: [29.62, 38.42]
# ID: 95, Predicted: 28.28, Actual: 37.64, 90% CI: [19.11, 37.45]
# ID: 96, Predicted: 27.71, Actual: 27.89, 90% CI: [18.32, 37.11]
# ID: 97, Predicted: 14.14, Actual: 7.00, 90% CI: [4.39, 23.88]
# ID: 98, Predicted: 15.27, Actual: 19.77, 90% CI: [-3.08, 33.62]
# ID: 99, Predicted: 15.90, Actual: 18.96, 90% CI: [13.29, 18.51]
# /home/yuki/miniconda3/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /home/yuki/miniconda3/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
